# %%
# Import packages
import nltk
import csv
import numpy as np
import pandas as pd

# %%
# Import WordNet dataset
from nltk.corpus import wordnet as wn

# %%
objects = []
objectStrings = []
objectSets = []

# %%
# Array of Target Objects
objects = ['baby', 'book', 'bottle', 'cat', 'dog', 'hand', 'shoe', 'spoon']

# WordNet Senses Corresponding to the target objects (hand coded by Ananya Mittal)
objectStrings = ['baby.n.01', 'book.n.01', 'bottle.n.01', 'cat.n.01', 
                 'dog.n.01',  'hand.n.01', 'shoe.n.01',   'spoon.n.01']

# Get synsets for target objects
for o in objectStrings:
    objectSets.append(wn.synset(o))

# %%
# Create DataFrame of all MCDI words, including hand coded senses for each word
mcdi_df = pd.read_csv('MCDI.csv')
mcdi_df.columns = ['words','entry','pos','sense','string']
data = mcdi_df[['words','string']]

# %%
# Check DF
mcdi_df
# Out:
#                     words                entry  pos  sense  \
# 0                airplane             airplane  .n.      1
# 1                  animal               animal  .n.      1
# 2                   apple                apple  .n.      1
# 3                     arm                  arm  .n.      1
# 4                    aunt                 aunt  .n.      1
# 5                    baby                 baby  .n.      1
# 6              babysitter           babysitter  .n.      1
# 7                backyard             backyard  .n.      1
# 8                    ball                 ball  .n.      1
# 9                 balloon              balloon  .n.      2
# 10                 banana               banana  .n.      2
# 11                   bath                 bath  .n.      2
# 12               bathroom               toilet  .n.      1
# 13                bathtub              bathtub  .n.      1
# 14                  beach                beach  .n.      1
# 15                  beads                beads  .n.      1
# 16                   bear                 bear  .n.      1
# 17                    bed                  bed  .n.      1
# 18                bedroom              bedroom  .n.      1
# 19                    bee                  bee  .n.      1
# 20           belly_button                navel  .n.      1
# 21                    bib                  bib  .n.      2
# 22                bicycle              bicycle  .n.      1
# 23                   bird                 bird  .n.      1
# 24                blanket              blanket  .n.      1
# 25                  block                block  .n.      3
# 26                  block                block  .n.      1
# 27                   book                 book  .n.      2
# 28                   book                 book  .n.      1
# 29                  boots                 boot  .n.      1
# ..                    ...                  ...  ...    ...
# 248                tongue               tongue  .n.      1
# 249                 tooth                tooth  .n.      1
# 250            toothbrush           toothbrush  .n.      1
# 251                 towel                towel  .n.      1
# 252                   toy            plaything  .n.      1
# 253                 train                train  .n.      1
# 254                 trash              rubbish  .n.      1
# 255                  tree                 tree  .n.      1
# 256                 truck                truck  .n.      1
# 257                 tummy              stomach  .n.      1
# 258                 tummy              abdomen  .n.      1
# 259                turtle               turtle  .n.      2
# 260                    TV  television_receiver  .n.      1
# 261                    TV           television  .n.      1
# 262                    TV           television  .n.      2
# 263                 uncle                uncle  .n.      1
# 264                vacuum               vacuum  .n.      4
# 265                  wait                 wait  .n.      1
# 266                  wait                delay  .n.      1
# 267               want to                 wish  .n.      1
# 268                 watch                watch  .n.      1
# 269                 water                water  .n.      6
# 270  water (not beverage)                water  .n.      1
# 271  water (not beverage)        body_of_water  .n.      1
# 272                window               window  .n.      1
# 273                window               window  .n.      2
# 274          work (place)            workplace  .n.      1
# 275                   yes                  yes  .n.      1
# 276                zipper       slide_fastener  .n.      1
# 277                   zoo            menagerie  .n.      2
#
#                        string
# 0               airplane.n.01
# 1                 animal.n.01
# 2                  apple.n.01
# 3                    arm.n.01
# 4                   aunt.n.01
# 5                   baby.n.01
# 6             babysitter.n.01
# 7               backyard.n.01
# 8                   ball.n.01
# 9                balloon.n.02
# 10                banana.n.02
# 11                  bath.n.02
# 12                toilet.n.01
# 13               bathtub.n.01
# 14                 beach.n.01
# 15                 beads.n.01
# 16                  bear.n.01
# 17                   bed.n.01
# 18               bedroom.n.01
# 19                   bee.n.01
# 20                 navel.n.01
# 21                   bib.n.02
# 22               bicycle.n.01
# 23                  bird.n.01
# 24               blanket.n.01
# 25                 block.n.03
# 26                 block.n.01
# 27                  book.n.02
# 28                  book.n.01
# 29                  boot.n.01
# ..                        ...
# 248               tongue.n.01
# 249                tooth.n.01
# 250           toothbrush.n.01
# 251                towel.n.01
# 252            plaything.n.01
# 253                train.n.01
# 254              rubbish.n.01
# 255                 tree.n.01
# 256                truck.n.01
# 257              stomach.n.01
# 258              abdomen.n.01
# 259               turtle.n.02
# 260  television_receiver.n.01
# 261           television.n.01
# 262           television.n.02
# 263                uncle.n.01
# 264               vacuum.n.04
# 265                 wait.n.01
# 266                delay.n.01
# 267                 wish.n.01
# 268                watch.n.01
# 269                water.n.06
# 270                water.n.01
# 271        body_of_water.n.01
# 272               window.n.01
# 273               window.n.02
# 274            workplace.n.01
# 275                  yes.n.01
# 276       slide_fastener.n.01
# 277            menagerie.n.02
#
# [278 rows x 5 columns]

# %%
# Get synsets for each word
def find_synset(st):
    try:
        return wn.synset(st)
    except:
        return None
mcdi_df['synset'] = mcdi_df['string'].map(lambda x: find_synset(x))

# %%
# Check DF
mcdi_df
# Out:
#                     words                entry  pos  sense  \
# 0                airplane             airplane  .n.      1
# 1                  animal               animal  .n.      1
# 2                   apple                apple  .n.      1
# 3                     arm                  arm  .n.      1
# 4                    aunt                 aunt  .n.      1
# 5                    baby                 baby  .n.      1
# 6              babysitter           babysitter  .n.      1
# 7                backyard             backyard  .n.      1
# 8                    ball                 ball  .n.      1
# 9                 balloon              balloon  .n.      2
# 10                 banana               banana  .n.      2
# 11                   bath                 bath  .n.      2
# 12               bathroom               toilet  .n.      1
# 13                bathtub              bathtub  .n.      1
# 14                  beach                beach  .n.      1
# 15                  beads                beads  .n.      1
# 16                   bear                 bear  .n.      1
# 17                    bed                  bed  .n.      1
# 18                bedroom              bedroom  .n.      1
# 19                    bee                  bee  .n.      1
# 20           belly_button                navel  .n.      1
# 21                    bib                  bib  .n.      2
# 22                bicycle              bicycle  .n.      1
# 23                   bird                 bird  .n.      1
# 24                blanket              blanket  .n.      1
# 25                  block                block  .n.      3
# 26                  block                block  .n.      1
# 27                   book                 book  .n.      2
# 28                   book                 book  .n.      1
# 29                  boots                 boot  .n.      1
# ..                    ...                  ...  ...    ...
# 248                tongue               tongue  .n.      1
# 249                 tooth                tooth  .n.      1
# 250            toothbrush           toothbrush  .n.      1
# 251                 towel                towel  .n.      1
# 252                   toy            plaything  .n.      1
# 253                 train                train  .n.      1
# 254                 trash              rubbish  .n.      1
# 255                  tree                 tree  .n.      1
# 256                 truck                truck  .n.      1
# 257                 tummy              stomach  .n.      1
# 258                 tummy              abdomen  .n.      1
# 259                turtle               turtle  .n.      2
# 260                    TV  television_receiver  .n.      1
# 261                    TV           television  .n.      1
# 262                    TV           television  .n.      2
# 263                 uncle                uncle  .n.      1
# 264                vacuum               vacuum  .n.      4
# 265                  wait                 wait  .n.      1
# 266                  wait                delay  .n.      1
# 267               want to                 wish  .n.      1
# 268                 watch                watch  .n.      1
# 269                 water                water  .n.      6
# 270  water (not beverage)                water  .n.      1
# 271  water (not beverage)        body_of_water  .n.      1
# 272                window               window  .n.      1
# 273                window               window  .n.      2
# 274          work (place)            workplace  .n.      1
# 275                   yes                  yes  .n.      1
# 276                zipper       slide_fastener  .n.      1
# 277                   zoo            menagerie  .n.      2
#
#                        string                              synset
# 0               airplane.n.01             Synset('airplane.n.01')
# 1                 animal.n.01               Synset('animal.n.01')
# 2                  apple.n.01                Synset('apple.n.01')
# 3                    arm.n.01                  Synset('arm.n.01')
# 4                   aunt.n.01                 Synset('aunt.n.01')
# 5                   baby.n.01                 Synset('baby.n.01')
# 6             babysitter.n.01           Synset('babysitter.n.01')
# 7               backyard.n.01             Synset('backyard.n.01')
# 8                   ball.n.01                 Synset('ball.n.01')
# 9                balloon.n.02              Synset('balloon.n.02')
# 10                banana.n.02               Synset('banana.n.02')
# 11                  bath.n.02                 Synset('bath.n.02')
# 12                toilet.n.01               Synset('toilet.n.01')
# 13               bathtub.n.01              Synset('bathtub.n.01')
# 14                 beach.n.01                Synset('beach.n.01')
# 15                 beads.n.01                Synset('beads.n.01')
# 16                  bear.n.01                 Synset('bear.n.01')
# 17                   bed.n.01                  Synset('bed.n.01')
# 18               bedroom.n.01              Synset('bedroom.n.01')
# 19                   bee.n.01                  Synset('bee.n.01')
# 20                 navel.n.01                Synset('navel.n.01')
# 21                   bib.n.02                  Synset('bib.n.02')
# 22               bicycle.n.01              Synset('bicycle.n.01')
# 23                  bird.n.01                 Synset('bird.n.01')
# 24               blanket.n.01              Synset('blanket.n.01')
# 25                 block.n.03                Synset('block.n.03')
# 26                 block.n.01                Synset('block.n.01')
# 27                  book.n.02                 Synset('book.n.02')
# 28                  book.n.01                 Synset('book.n.01')
# 29                  boot.n.01                 Synset('boot.n.01')
# ..                        ...                                 ...
# 248               tongue.n.01               Synset('tongue.n.01')
# 249                tooth.n.01                Synset('tooth.n.01')
# 250           toothbrush.n.01           Synset('toothbrush.n.01')
# 251                towel.n.01                Synset('towel.n.01')
# 252            plaything.n.01            Synset('plaything.n.01')
# 253                train.n.01                Synset('train.n.01')
# 254              rubbish.n.01              Synset('rubbish.n.01')
# 255                 tree.n.01                 Synset('tree.n.01')
# 256                truck.n.01                Synset('truck.n.01')
# 257              stomach.n.01              Synset('stomach.n.01')
# 258              abdomen.n.01              Synset('abdomen.n.01')
# 259               turtle.n.02               Synset('turtle.n.02')
# 260  television_receiver.n.01  Synset('television_receiver.n.01')
# 261           television.n.01           Synset('television.n.01')
# 262           television.n.02           Synset('television.n.02')
# 263                uncle.n.01                Synset('uncle.n.01')
# 264               vacuum.n.04               Synset('vacuum.n.04')
# 265                 wait.n.01                Synset('delay.n.01')
# 266                delay.n.01                Synset('delay.n.01')
# 267                 wish.n.01                 Synset('wish.n.01')
# 268                watch.n.01                Synset('watch.n.01')
# 269                water.n.06                Synset('water.n.06')
# 270                water.n.01                Synset('water.n.01')
# 271        body_of_water.n.01        Synset('body_of_water.n.01')
# 272               window.n.01               Synset('window.n.01')
# 273               window.n.02               Synset('window.n.02')
# 274            workplace.n.01            Synset('workplace.n.01')
# 275                  yes.n.01                  Synset('yes.n.01')
# 276       slide_fastener.n.01       Synset('slide_fastener.n.01')
# 277            menagerie.n.02            Synset('menagerie.n.02')
#
# [278 rows x 6 columns]

# %%
# Create DFs to store similarity ratings (OBJECTS x MCDI)
similarity_df_PL = pd.DataFrame(0.0, index=range(len(mcdi_df['words'])), columns=range(len(objects)))
similarity_df_LCH = pd.DataFrame(0.0, index=range(len(mcdi_df['words'])), columns=range(len(objects)))
similarity_df_WUP = pd.DataFrame(0.0, index=range(len(mcdi_df['words'])), columns=range(len(objects)))

# %%
## Create DFs to store similarity ratings (OBJECTS x OBJECTS)
#similarity_df_PL = pd.DataFrame(0.0, index=range(len(objects)), columns=range(len(objects)))
#similarity_df_LCH = pd.DataFrame(0.0, index=range(len(objects)), columns=range(len(objects)))
#similarity_df_WUP = pd.DataFrame(0.0, index=range(len(objects)), columns=range(len(objects)))

# %%
## Create DFs to store similarity ratings (MCDI x MCDI)
#similarity_df_PL = pd.DataFrame(0.0, index=range(len(mcdi_df['words'])), columns=range(len(mcdi_df['words'])))
#similarity_df_LCH = pd.DataFrame(0.0, index=range(len(mcdi_df['words'])), columns=range(len(mcdi_df['words'])))
#similarity_df_WUP = pd.DataFrame(0.0, index=range(len(mcdi_df['words'])), columns=range(len(mcdi_df['words'])))

# %%
# Helper function: check if a given word has synsets
def has_synset(st):
    if st is None: return False
    else: return True

# %%
# For each word in the MCDI, check that they all have synsets
i = 0
j = 0
index_ct = 0

for st in mcdi_df['synset']:
    if has_synset(st) == False: 
        i = i+1
        print(index_ct)
        
    else: j = j+1
        
    index_ct = index_ct+1
    
print("Number of words that do not have any synsets: ", i)
print("Number of words that do have synsets        : ", j)
# Out:
# Number of words that do not have any synsets:  0
# Number of words that do have synsets        :  278

# %%
# Test: Path length similarity between BABY and babysitter
if(has_synset(mcdi_df['synset'][6])==True):
    similarity_df_PL[0][6] = objectSets[0].path_similarity(mcdi_df['synset'][6])
print("similarity = ", round(similarity_df_PL[0][6],3))
# Out:
# similarity =  0.111

# %%
# Populate similarity DFs using different measures of similarity
for w in range(len(mcdi_df['words'])): 
#for o1 in range(len(objects)): 
    for o in range(len(objects)): 
    #for w2 in range(len(mcdi_df['words'])): 
        if(has_synset(mcdi_df['synset'][w])==True):
            similarity_df_PL[o][w] = objectSets[o].path_similarity(mcdi_df['synset'][w])
            similarity_df_LCH[o][w] = objectSets[o].lch_similarity(mcdi_df['synset'][w])
            similarity_df_WUP[o][w] = objectSets[o].wup_similarity(mcdi_df['synset'][w])
        else:
            similarity_df_PL[o][w] = None
            similarity_df_LCH[o][w] = None
            similarity_df_WUP[o][w] = None

# %%
similarity_df_PL
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.062500  0.076923  0.100000  0.052632  0.071429  0.058824  0.090909
# 1    0.142857  0.100000  0.111111  0.125000  0.333333  0.083333  0.125000
# 2    0.076923  0.071429  0.076923  0.055556  0.076923  0.076923  0.083333
# 3    0.071429  0.062500  0.066667  0.050000  0.066667  0.166667  0.071429
# 263  0.166667  0.076923  0.083333  0.076923  0.125000  0.083333  0.090909
# 264  0.066667  0.083333  0.090909  0.055556  0.076923  0.062500  0.100000
# 265  0.076923  0.066667  0.071429  0.052632  0.071429  0.076923  0.076923
# 266  0.076923  0.066667  0.071429  0.052632  0.071429  0.076923  0.076923
# 267  0.071429  0.062500  0.066667  0.050000  0.066667  0.071429  0.071429
# 268  0.066667  0.083333  0.111111  0.055556  0.076923  0.062500  0.100000
# 269  0.090909  0.076923  0.083333  0.058824  0.083333  0.090909  0.090909
# 270  0.090909  0.076923  0.083333  0.058824  0.083333  0.090909  0.090909
# 271  0.111111  0.090909  0.100000  0.066667  0.100000  0.142857  0.111111
# 272  0.076923  0.100000  0.111111  0.062500  0.090909  0.071429  0.125000
# 273  0.090909  0.125000  0.142857  0.071429  0.111111  0.083333  0.166667
# 274  0.083333  0.083333  0.090909  0.062500  0.090909  0.083333  0.100000
# 275  0.058824  0.052632  0.055556  0.043478  0.055556  0.058824  0.058824
# 276  0.071429  0.090909  0.125000  0.058824  0.083333  0.066667  0.111111
# 277  0.090909  0.125000  0.142857  0.071429  0.111111  0.083333  0.166667
#
#             7
# 0    0.111111
# 1    0.125000
# 2    0.083333
# 3    0.071429
# 4    0.090909
# 5    0.083333
# 6    0.083333
# 7    0.076923
# 8    0.166667
# 9    0.166667
# 10   0.083333
# 11   0.058824
# 12   0.125000
# 13   0.250000
# 14   0.125000
# 15   0.076923
# 16   0.071429
# 17   0.142857
# 18   0.125000
# 19   0.076923
# 20   0.111111
# 21   0.090909
# 22   0.250000
# 23   0.090909
# 24   0.125000
# 25   0.076923
# 26   0.200000
# 27   0.142857
# 28   0.111111
# 29   0.142857
# ..        ...
# 248  0.083333
# 249  0.066667
# 250  0.200000
# 251  0.142857
# 252  0.200000
# 253  0.166667
# 254  0.083333
# 255  0.090909
# 256  0.166667
# 257  0.076923
# 258  0.090909
# 259  0.071429
# 260  0.125000
# 261  0.142857
# 262  0.142857
# 263  0.090909
# 264  0.100000
# 265  0.076923
# 266  0.076923
# 267  0.071429
# 268  0.125000
# 269  0.090909
# 270  0.090909
# 271  0.111111
# 272  0.125000
# 273  0.166667
# 274  0.100000
# 275  0.058824
# 276  0.142857
# 277  0.166667
#
# [278 rows x 8 columns]

# %%
# Format DFs
similarity_df_PL.columns = ['BABY', 'BOOK', 'BOTTLE', 'CAT', 'DOG', 'HAND', 'SHOE', 'SPOON']
similarity_df_LCH.columns = ['BABY', 'BOOK', 'BOTTLE', 'CAT', 'DOG', 'HAND', 'SHOE', 'SPOON']
similarity_df_WUP.columns = ['BABY', 'BOOK', 'BOTTLE', 'CAT', 'DOG', 'HAND', 'SHOE', 'SPOON']

similarity_df_PL.rename(index = mcdi_df['words'])
similarity_df_LCH.rename(index = mcdi_df['words'])
similarity_df_WUP.rename(index = mcdi_df['words'])

similarity_df_PL['words'] = mcdi_df['words']
similarity_df_LCH['words'] = mcdi_df['words']
similarity_df_WUP['words'] = mcdi_df['words']

similarity_df_WUP
# Out:
#          BABY      BOOK    BOTTLE       CAT       DOG      HAND      SHOE  \
# 0    0.347826  0.454545  0.571429  0.307692  0.380952  0.200000  0.500000
# 1    0.666667  0.470588  0.500000  0.666667  0.875000  0.266667  0.533333
# 261  0.380952  0.500000  0.631579  0.333333  0.421053  0.222222  0.555556
# 262  0.380952  0.500000  0.631579  0.333333  0.421053  0.222222  0.555556
# 263  0.571429  0.400000  0.421053  0.500000  0.631579  0.266667  0.444444
# 264  0.363636  0.476190  0.500000  0.320000  0.400000  0.210526  0.526316
# 265  0.142857  0.125000  0.133333  0.100000  0.133333  0.142857  0.142857
# 266  0.142857  0.125000  0.133333  0.100000  0.133333  0.142857  0.142857
# 267  0.133333  0.117647  0.125000  0.095238  0.125000  0.133333  0.133333
# 268  0.363636  0.476190  0.600000  0.320000  0.400000  0.210526  0.526316
# 269  0.285714  0.250000  0.266667  0.200000  0.266667  0.285714  0.285714
# 270  0.285714  0.250000  0.266667  0.200000  0.266667  0.285714  0.285714
# 271  0.333333  0.285714  0.307692  0.222222  0.307692  0.500000  0.333333
# 272  0.400000  0.526316  0.555556  0.347826  0.444444  0.235294  0.588235
# 273  0.444444  0.588235  0.625000  0.380952  0.500000  0.266667  0.666667
# 274  0.352941  0.352941  0.375000  0.285714  0.375000  0.266667  0.400000
# 275  0.111111  0.100000  0.105263  0.083333  0.105263  0.111111  0.111111
# 276  0.380952  0.500000  0.631579  0.333333  0.421053  0.222222  0.555556
# 277  0.444444  0.588235  0.625000  0.380952  0.500000  0.266667  0.666667
#
#         SPOON                 words
# 0    0.600000              airplane
# 1    0.533333                animal
# 2    0.421053                 apple
# 3    0.235294                   arm
# 4    0.444444                  aunt
# 5    0.421053                  baby
# 6    0.421053            babysitter
# 7    0.333333              backyard
# 8    0.705882                  ball
# 9    0.666667               balloon
# 10   0.421053                banana
# 11   0.111111                  bath
# 12   0.588235              bathroom
# 13   0.823529               bathtub
# 14   0.461538                 beach
# 15   0.142857                 beads
# 16   0.380952                  bear
# 17   0.666667                   bed
# 18   0.588235               bedroom
# 19   0.400000                   bee
# 20   0.428571          belly_button
# 21   0.500000                   bib
# 22   0.823529               bicycle
# 23   0.444444                  bird
# 24   0.588235               blanket
# 25   0.142857                 block
# 26   0.714286                 block
# 27   0.625000                  book
# 28   0.555556                  book
# 29   0.625000                 boots
# ..        ...                   ...
# 248  0.266667                tongue
# 249  0.222222                 tooth
# 250  0.750000            toothbrush
# 251  0.625000                 towel
# 252  0.714286                   toy
# 253  0.705882                 train
# 254  0.266667                 trash
# 255  0.444444                  tree
# 256  0.736842                 truck
# 257  0.250000                 tummy
# 258  0.285714                 tummy
# 259  0.380952                turtle
# 260  0.631579                    TV
# 261  0.666667                    TV
# 262  0.666667                    TV
# 263  0.444444                 uncle
# 264  0.526316                vacuum
# 265  0.142857                  wait
# 266  0.142857                  wait
# 267  0.133333               want to
# 268  0.631579                 watch
# 269  0.285714                 water
# 270  0.285714  water (not beverage)
# 271  0.333333  water (not beverage)
# 272  0.588235                window
# 273  0.666667                window
# 274  0.400000          work (place)
# 275  0.111111                   yes
# 276  0.666667                zipper
# 277  0.666667                   zoo
#
# [278 rows x 9 columns]

# %%
# Sanity Check: Test BABY
simA_ind_BABY = similarity_df_PL.sort_values(by=['BABY'], axis = 0, ascending = False)[0:12]['BABY']
simB_ind_BABY = similarity_df_LCH.sort_values(by=['BABY'], axis = 0, ascending = False)[0:12]['BABY']
simC_ind_BABY = similarity_df_WUP.sort_values(by=['BABY'], axis = 0, ascending = False)[0:12]['BABY']

print(simA_ind_BABY)
print(simB_ind_BABY)
print(simC_ind_BABY)

# 62  = child
# 182 = person
# 263 = plant
# 4   = aunt
# 188 = animal
# 1   = dog
# 35  = man
# 39  = boy
# 110 = sister
# 61  = child
# 142 = brother
# 81  = bird
# 195 = lady
# 109 = lady
# Out:
# 5      1.000000
# 62     0.500000
# 182    0.200000
# 263    0.166667
# 4      0.166667
# 188    0.142857
# 1      0.142857
# 35     0.142857
# 39     0.142857
# 110    0.142857
# 61     0.142857
# 142    0.142857
# Name: BABY, dtype: float64
# 5      3.637586
# 62     2.944439
# 182    2.028148
# 263    1.845827
# 4      1.845827
# 188    1.691676
# 1      1.691676
# 35     1.691676
# 39     1.691676
# 110    1.691676
# 61     1.691676
# 142    1.691676
# Name: BABY, dtype: float64
# 5      1.000000
# 62     0.952381
# 1      0.666667
# 188    0.666667
# 182    0.666667
# 142    0.600000
# 110    0.600000
# 81     0.600000
# 35     0.600000
# 61     0.600000
# 195    0.571429
# 109    0.571429
# Name: BABY, dtype: float64

# %%
# Sanity Check: Test BOOK
simA_ind_BOOK = similarity_df_PL.sort_values(by=['BOOK'], axis = 0, ascending = False)[1:12]['BOOK']
simB_ind_BOOK = similarity_df_LCH.sort_values(by=['BOOK'], axis = 0, ascending = False)[1:12]['BOOK']
simC_ind_BOOK = similarity_df_WUP.sort_values(by=['BOOK'], axis = 0, ascending = False)[1:12]['BOOK']

print(simA_ind_BOOK)
print(simB_ind_BOOK)
print(simC_ind_BOOK)

# 215 = toy
# 161 = picture
# 25  = block
# 75  = doll
# 45  = cake
# 169 = pool
# 234 = zoo
# 78  = drawer
# 170 = potty
# 73  = dish
# 196 = stairs
# 30  = box
# 183 = shoe
# Out:
# 27     0.200000
# 252    0.142857
# 184    0.142857
# 26     0.142857
# 183    0.142857
# 241    0.125000
# 238    0.125000
# 222    0.125000
# 82     0.125000
# 192    0.125000
# 277    0.125000
# Name: BOOK, dtype: float64
# 27     2.028148
# 252    1.691676
# 184    1.691676
# 26     1.691676
# 183    1.691676
# 241    1.558145
# 238    1.558145
# 222    1.558145
# 82     1.558145
# 192    1.558145
# 277    1.558145
# Name: BOOK, dtype: float64
# 27     0.777778
# 184    0.666667
# 183    0.666667
# 252    0.625000
# 26     0.625000
# 222    0.588235
# 192    0.588235
# 238    0.588235
# 82     0.588235
# 241    0.588235
# 277    0.588235
# Name: BOOK, dtype: float64

# %%
## Save Object x Words Models to CSVs
#similarity_df_PL.to_csv('path_similarity_OxW.csv')
#similarity_df_LCH.to_csv('lch_similarity_OxW.csv')
#similarity_df_WUP.to_csv('wup_similarity_OxW.csv')

# %%
## Save Object x Objects Models to CSVs
#similarity_df_PL.to_csv('path_similarity_OxO.csv')
#similarity_df_LCH.to_csv('lch_similarity_OxO.csv')
#similarity_df_WUP.to_csv('wup_similarity_OxO.csv')

# %%
## Save Words x Words Models to CSVs
#similarity_df_PL.to_csv('path_similarity_WxW.csv')
#similarity_df_LCH.to_csv('lch_similarity_WxW.csv')
#similarity_df_WUP.to_csv('wup_similarity_WxW.csv')
